# %% [markdown]
# L'installation [Elasticité dynamique](https://github.com/laurentperrinet/elasticite) agit comme un filtre et génère de nouveaux espaces démultipliés, comme un empilement quasi infini d'horizons. Par principe de réflexion, la pièce absorbe l'image de l'environnement et accumule les points de vue ; le mouvement permanent requalifie continuellement ce qui est regardé et entendu.
#
# Ce post simule une configuration de contrôle sur l'ensemble de la structure.
#
# <!-- TEASER_END -->

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import elasticite as el
import numpy as np
#duration = el.get_default_args(el.EdgeGrid.render)['duration']

# %%
# %%writefile ../scenario_line_contraint.py
#!/usr/bin/env python
# -*- coding: utf8 -*-

"""

Sur une ligne de lames, on fait tourner les lames avec un mouvement relativement élastique mais exogene (prédeterminé, pas émergent)

"""

import elasticite as el
import numpy as np

class EdgeGrid(el.EdgeGrid):
    def update(self):
        if self.structure: N_lame = self.N_lame-self.struct_N
        else: N_lame = self.N_lame
        self.lames[2, :N_lame] = 90.* np.pi/180. * np.sin(2*np.pi*(self.t)/self.period)

if __name__ == "__main__":
    import sys
    if len(sys.argv)>1: mode = sys.argv[1]
    else: mode = 'both'

    #e = EdgeGrid(N_lame=25, grid_type='line', mode=mode, verb=False, period=60)
    # to test writing / reading from a file
    e = EdgeGrid(N_lame=25, grid_type='line', mode=mode, verb=True, period=30, filename='mat/line_contraint.npy')
    el.main(e)
# Out:
# Overwriting ../scenario_line_contraint.py

# %%
#!rm mat/line_contraint.npy
# %cd ..
# %run  scenario_line_contraint.py writer
# %cd posts
# Out:
# /Users/laurentperrinet/cloud_nas/science/2016-01-13_elasticite_github
# recording at t= 0.0
# recording at t= 0.0333333333333
# recording at t= 0.0666666666667
# recording at t= 0.1
# recording at t= 0.133333333333
# recording at t= 0.166666666667
# recording at t= 0.2
# recording at t= 0.233333333333
# recording at t= 0.266666666667
# recording at t= 0.3
# recording at t= 0.333333333333
# recording at t= 0.366666666667
# recording at t= 0.4
# recording at t= 0.433333333333
# recording at t= 0.466666666667
# recording at t= 0.5
# recording at t= 0.533333333333
# recording at t= 0.566666666667
# recording at t= 0.6
# recording at t= 0.633333333333
# recording at t= 0.666666666667
# recording at t= 0.7
# recording at t= 0.733333333333
# recording at t= 0.766666666667
# recording at t= 0.8
# recording at t= 0.833333333333
# recording at t= 0.866666666667
# recording at t= 0.9
# recording at t= 0.933333333333
# recording at t= 0.966666666667
# recording at t= 1.0
# recording at t= 1.03333333333
# recording at t= 1.06666666667
# recording at t= 1.1
# recording at t= 1.13333333333
# recording at t= 1.16666666667
# recording at t= 1.2
# recording at t= 1.23333333333
# recording at t= 1.26666666667
# recording at t= 1.3
# recording at t= 1.33333333333
# recording at t= 1.36666666667
# recording at t= 1.4
# recording at t= 1.43333333333
# recording at t= 1.46666666667
# recording at t= 1.5
# recording at t= 1.53333333333
# recording at t= 1.56666666667
# recording at t= 1.6
# recording at t= 1.63333333333
# recording at t= 1.66666666667
# recording at t= 1.7
# recording at t= 1.73333333333
# recording at t= 1.76666666667
# recording at t= 1.8
# recording at t= 1.83333333333
# recording at t= 1.86666666667
# recording at t= 1.9
# recording at t= 1.93333333333
# recording at t= 1.96666666667
# recording at t= 2.0
# recording at t= 2.03333333333
# recording at t= 2.06666666667
# recording at t= 2.1
# recording at t= 2.13333333333
# recording at t= 2.16666666667
# recording at t= 2.2
# recording at t= 2.23333333333
# recording at t= 2.26666666667
# recording at t= 2.3
# recording at t= 2.33333333333
# recording at t= 2.36666666667
# recording at t= 2.4
# recording at t= 2.43333333333
# recording at t= 2.46666666667
# recording at t= 2.5
# recording at t= 2.53333333333
# recording at t= 2.56666666667
# recording at t= 2.6
# recording at t= 2.63333333333
# recording at t= 2.66666666667
# recording at t= 2.7
# recording at t= 2.73333333333
# recording at t= 2.76666666667
# recording at t= 2.8
# recording at t= 2.83333333333
# recording at t= 2.86666666667
# recording at t= 2.9
# recording at t= 2.93333333333
# recording at t= 2.96666666667
# recording at t= 3.0
# recording at t= 3.03333333333
# recording at t= 3.06666666667
# recording at t= 3.1
# recording at t= 3.13333333333
# recording at t= 3.16666666667
# recording at t= 3.2
# recording at t= 3.23333333333
# recording at t= 3.26666666667
# recording at t= 3.3
# recording at t= 3.33333333333
# recording at t= 3.36666666667
# recording at t= 3.4
# recording at t= 3.43333333333
# recording at t= 3.46666666667
# recording at t= 3.5
# recording at t= 3.53333333333
# recording at t= 3.56666666667
# recording at t= 3.6
# recording at t= 3.63333333333
# recording at t= 3.66666666667
# recording at t= 3.7
# recording at t= 3.73333333333
# recording at t= 3.76666666667
# recording at t= 3.8
# recording at t= 3.83333333333
# recording at t= 3.86666666667
# recording at t= 3.9
# recording at t= 3.93333333333
# recording at t= 3.96666666667
# recording at t= 4.0
# recording at t= 4.03333333333
# recording at t= 4.06666666667
# recording at t= 4.1
# recording at t= 4.13333333333
# recording at t= 4.16666666667
# recording at t= 4.2
# recording at t= 4.23333333333
# recording at t= 4.26666666667
# recording at t= 4.3
# recording at t= 4.33333333333
# recording at t= 4.36666666667
# recording at t= 4.4
# recording at t= 4.43333333333
# recording at t= 4.46666666667
# recording at t= 4.5
# recording at t= 4.53333333333
# recording at t= 4.56666666667
# recording at t= 4.6
# recording at t= 4.63333333333
# recording at t= 4.66666666667
# recording at t= 4.7
# recording at t= 4.73333333333
# recording at t= 4.76666666667
# recording at t= 4.8
# recording at t= 4.83333333333
# recording at t= 4.86666666667
# recording at t= 4.9
# recording at t= 4.93333333333
# recording at t= 4.96666666667
# recording at t= 5.0
# recording at t= 5.03333333333
# recording at t= 5.06666666667
# recording at t= 5.1
# recording at t= 5.13333333333
# recording at t= 5.16666666667
# recording at t= 5.2
# recording at t= 5.23333333333
# recording at t= 5.26666666667
# recording at t= 5.3
# recording at t= 5.33333333333
# recording at t= 5.36666666667
# recording at t= 5.4
# recording at t= 5.43333333333
# recording at t= 5.46666666667
# recording at t= 5.5
# recording at t= 5.53333333333
# recording at t= 5.56666666667
# recording at t= 5.6
# recording at t= 5.63333333333
# recording at t= 5.66666666667
# recording at t= 5.7
# recording at t= 5.73333333333
# recording at t= 5.76666666667
# recording at t= 5.8
# recording at t= 5.83333333333
# recording at t= 5.86666666667
# recording at t= 5.9
# recording at t= 5.93333333333
# recording at t= 5.96666666667
# recording at t= 6.0
# recording at t= 6.03333333333
# recording at t= 6.06666666667
# recording at t= 6.1
# recording at t= 6.13333333333
# recording at t= 6.16666666667
# recording at t= 6.2
# recording at t= 6.23333333333
# recording at t= 6.26666666667
# recording at t= 6.3
# recording at t= 6.33333333333
# recording at t= 6.36666666667
# recording at t= 6.4
# recording at t= 6.43333333333
# recording at t= 6.46666666667
# recording at t= 6.5
# recording at t= 6.53333333333
# recording at t= 6.56666666667
# recording at t= 6.6
# recording at t= 6.63333333333
# recording at t= 6.66666666667
# recording at t= 6.7
# recording at t= 6.73333333333
# recording at t= 6.76666666667
# recording at t= 6.8
# recording at t= 6.83333333333
# recording at t= 6.86666666667
# recording at t= 6.9
# recording at t= 6.93333333333
# recording at t= 6.96666666667
# recording at t= 7.0
# recording at t= 7.03333333333
# recording at t= 7.06666666667
# recording at t= 7.1
# recording at t= 7.13333333333
# recording at t= 7.16666666667
# recording at t= 7.2
# recording at t= 7.23333333333
# recording at t= 7.26666666667
# recording at t= 7.3
# recording at t= 7.33333333333
# recording at t= 7.36666666667
# recording at t= 7.4
# recording at t= 7.43333333333
# recording at t= 7.46666666667
# recording at t= 7.5
# recording at t= 7.53333333333
# recording at t= 7.56666666667
# recording at t= 7.6
# recording at t= 7.63333333333
# recording at t= 7.66666666667
# recording at t= 7.7
# recording at t= 7.73333333333
# recording at t= 7.76666666667
# recording at t= 7.8
# recording at t= 7.83333333333
# recording at t= 7.86666666667
# recording at t= 7.9
# recording at t= 7.93333333333
# recording at t= 7.96666666667
# recording at t= 8.0
# recording at t= 8.03333333333
# recording at t= 8.06666666667
# recording at t= 8.1
# recording at t= 8.13333333333
# recording at t= 8.16666666667
# recording at t= 8.2
# recording at t= 8.23333333333
# recording at t= 8.26666666667
# recording at t= 8.3
# recording at t= 8.33333333333
# recording at t= 8.36666666667
# recording at t= 8.4
# recording at t= 8.43333333333
# recording at t= 8.46666666667
# recording at t= 8.5
# recording at t= 8.53333333333
# recording at t= 8.56666666667
# recording at t= 8.6
# recording at t= 8.63333333333
# recording at t= 8.66666666667
# recording at t= 8.7
# recording at t= 8.73333333333
# recording at t= 8.76666666667
# recording at t= 8.8
# recording at t= 8.83333333333
# recording at t= 8.86666666667
# recording at t= 8.9
# recording at t= 8.93333333333
# recording at t= 8.96666666667
# recording at t= 9.0
# recording at t= 9.03333333333
# recording at t= 9.06666666667
# recording at t= 9.1
# recording at t= 9.13333333333
# recording at t= 9.16666666667
# recording at t= 9.2
# recording at t= 9.23333333333
# recording at t= 9.26666666667
# recording at t= 9.3
# recording at t= 9.33333333333
# recording at t= 9.36666666667
# recording at t= 9.4
# recording at t= 9.43333333333
# recording at t= 9.46666666667
# recording at t= 9.5
# recording at t= 9.53333333333
# recording at t= 9.56666666667
# recording at t= 9.6
# recording at t= 9.63333333333
# recording at t= 9.66666666667
# recording at t= 9.7
# recording at t= 9.73333333333
# recording at t= 9.76666666667
# recording at t= 9.8
# recording at t= 9.83333333333
# recording at t= 9.86666666667
# recording at t= 9.9
# recording at t= 9.93333333333
# recording at t= 9.96666666667
# recording at t= 10.0
# recording at t= 10.0333333333
# recording at t= 10.0666666667
# recording at t= 10.1
# recording at t= 10.1333333333
# recording at t= 10.1666666667
# recording at t= 10.2
# recording at t= 10.2333333333
# recording at t= 10.2666666667
# recording at t= 10.3
# recording at t= 10.3333333333
# recording at t= 10.3666666667
# recording at t= 10.4
# recording at t= 10.4333333333
# recording at t= 10.4666666667
# recording at t= 10.5
# recording at t= 10.5333333333
# recording at t= 10.5666666667
# recording at t= 10.6
# recording at t= 10.6333333333
# recording at t= 10.6666666667
# recording at t= 10.7
# recording at t= 10.7333333333
# recording at t= 10.7666666667
# recording at t= 10.8
# recording at t= 10.8333333333
# recording at t= 10.8666666667
# recording at t= 10.9
# recording at t= 10.9333333333
# recording at t= 10.9666666667
# recording at t= 11.0
# recording at t= 11.0333333333
# recording at t= 11.0666666667
# recording at t= 11.1
# recording at t= 11.1333333333
# recording at t= 11.1666666667
# recording at t= 11.2
# recording at t= 11.2333333333
# recording at t= 11.2666666667
# recording at t= 11.3
# recording at t= 11.3333333333
# recording at t= 11.3666666667
# recording at t= 11.4
# recording at t= 11.4333333333
# recording at t= 11.4666666667
# recording at t= 11.5
# recording at t= 11.5333333333
# recording at t= 11.5666666667
# recording at t= 11.6
# recording at t= 11.6333333333
# recording at t= 11.6666666667
# recording at t= 11.7
# recording at t= 11.7333333333
# recording at t= 11.7666666667
# recording at t= 11.8
# recording at t= 11.8333333333
# recording at t= 11.8666666667
# recording at t= 11.9
# recording at t= 11.9333333333
# recording at t= 11.9666666667
# recording at t= 12.0
# recording at t= 12.0333333333
# recording at t= 12.0666666667
# recording at t= 12.1
# recording at t= 12.1333333333
# recording at t= 12.1666666667
# recording at t= 12.2
# recording at t= 12.2333333333
# recording at t= 12.2666666667
# recording at t= 12.3
# recording at t= 12.3333333333
# recording at t= 12.3666666667
# recording at t= 12.4
# recording at t= 12.4333333333
# recording at t= 12.4666666667
# recording at t= 12.5
# recording at t= 12.5333333333
# recording at t= 12.5666666667
# recording at t= 12.6
# recording at t= 12.6333333333
# recording at t= 12.6666666667
# recording at t= 12.7
# recording at t= 12.7333333333
# recording at t= 12.7666666667
# recording at t= 12.8
# recording at t= 12.8333333333
# recording at t= 12.8666666667
# recording at t= 12.9
# recording at t= 12.9333333333
# recording at t= 12.9666666667
# recording at t= 13.0
# recording at t= 13.0333333333
# recording at t= 13.0666666667
# recording at t= 13.1
# recording at t= 13.1333333333
# recording at t= 13.1666666667
# recording at t= 13.2
# recording at t= 13.2333333333
# recording at t= 13.2666666667
# recording at t= 13.3
# recording at t= 13.3333333333
# recording at t= 13.3666666667
# recording at t= 13.4
# recording at t= 13.4333333333
# recording at t= 13.4666666667
# recording at t= 13.5
# recording at t= 13.5333333333
# recording at t= 13.5666666667
# recording at t= 13.6
# recording at t= 13.6333333333
# recording at t= 13.6666666667
# recording at t= 13.7
# recording at t= 13.7333333333
# recording at t= 13.7666666667
# recording at t= 13.8
# recording at t= 13.8333333333
# recording at t= 13.8666666667
# recording at t= 13.9
# recording at t= 13.9333333333
# recording at t= 13.9666666667
# recording at t= 14.0
# recording at t= 14.0333333333
# recording at t= 14.0666666667
# recording at t= 14.1
# recording at t= 14.1333333333
# recording at t= 14.1666666667
# recording at t= 14.2
# recording at t= 14.2333333333
# recording at t= 14.2666666667
# recording at t= 14.3
# recording at t= 14.3333333333
# recording at t= 14.3666666667
# recording at t= 14.4
# recording at t= 14.4333333333
# recording at t= 14.4666666667
# recording at t= 14.5
# recording at t= 14.5333333333
# recording at t= 14.5666666667
# recording at t= 14.6
# recording at t= 14.6333333333
# recording at t= 14.6666666667
# recording at t= 14.7
# recording at t= 14.7333333333
# recording at t= 14.7666666667
# recording at t= 14.8
# recording at t= 14.8333333333
# recording at t= 14.8666666667
# recording at t= 14.9
# recording at t= 14.9333333333
# recording at t= 14.9666666667
# recording at t= 15.0
# recording at t= 15.0333333333
# recording at t= 15.0666666667
# recording at t= 15.1
# recording at t= 15.1333333333
# recording at t= 15.1666666667
# recording at t= 15.2
# recording at t= 15.2333333333
# recording at t= 15.2666666667
# recording at t= 15.3
# recording at t= 15.3333333333
# recording at t= 15.3666666667
# recording at t= 15.4
# recording at t= 15.4333333333
# recording at t= 15.4666666667
# recording at t= 15.5
# recording at t= 15.5333333333
# recording at t= 15.5666666667
# recording at t= 15.6
# recording at t= 15.6333333333
# recording at t= 15.6666666667
# recording at t= 15.7
# recording at t= 15.7333333333
# recording at t= 15.7666666667
# recording at t= 15.8
# recording at t= 15.8333333333
# recording at t= 15.8666666667
# recording at t= 15.9
# recording at t= 15.9333333333
# recording at t= 15.9666666667
# recording at t= 16.0
# recording at t= 16.0333333333
# recording at t= 16.0666666667
# recording at t= 16.1
# recording at t= 16.1333333333
# recording at t= 16.1666666667
# recording at t= 16.2
# recording at t= 16.2333333333
# recording at t= 16.2666666667
# recording at t= 16.3
# recording at t= 16.3333333333
# recording at t= 16.3666666667
# recording at t= 16.4
# recording at t= 16.4333333333
# recording at t= 16.4666666667
# recording at t= 16.5
# recording at t= 16.5333333333
# recording at t= 16.5666666667
# recording at t= 16.6
# recording at t= 16.6333333333
# recording at t= 16.6666666667
# recording at t= 16.7
# recording at t= 16.7333333333
# recording at t= 16.7666666667
# recording at t= 16.8
# recording at t= 16.8333333333
# recording at t= 16.8666666667
# recording at t= 16.9
# recording at t= 16.9333333333
# recording at t= 16.9666666667
# recording at t= 17.0
# recording at t= 17.0333333333
# recording at t= 17.0666666667
# recording at t= 17.1
# recording at t= 17.1333333333
# recording at t= 17.1666666667
# recording at t= 17.2
# recording at t= 17.2333333333
# recording at t= 17.2666666667
# recording at t= 17.3
# recording at t= 17.3333333333
# recording at t= 17.3666666667
# recording at t= 17.4
# recording at t= 17.4333333333
# recording at t= 17.4666666667
# recording at t= 17.5
# recording at t= 17.5333333333
# recording at t= 17.5666666667
# recording at t= 17.6
# recording at t= 17.6333333333
# recording at t= 17.6666666667
# recording at t= 17.7
# recording at t= 17.7333333333
# recording at t= 17.7666666667
# recording at t= 17.8
# recording at t= 17.8333333333
# recording at t= 17.8666666667
# recording at t= 17.9
# recording at t= 17.9333333333
# recording at t= 17.9666666667
# recording at t= 18.0
# recording at t= 18.0333333333
# recording at t= 18.0666666667
# recording at t= 18.1
# recording at t= 18.1333333333
# recording at t= 18.1666666667
# recording at t= 18.2
# recording at t= 18.2333333333
# recording at t= 18.2666666667
# recording at t= 18.3
# recording at t= 18.3333333333
# recording at t= 18.3666666667
# recording at t= 18.4
# recording at t= 18.4333333333
# recording at t= 18.4666666667
# recording at t= 18.5
# recording at t= 18.5333333333
# recording at t= 18.5666666667
# recording at t= 18.6
# recording at t= 18.6333333333
# recording at t= 18.6666666667
# recording at t= 18.7
# recording at t= 18.7333333333
# recording at t= 18.7666666667
# recording at t= 18.8
# recording at t= 18.8333333333
# recording at t= 18.8666666667
# recording at t= 18.9
# recording at t= 18.9333333333
# recording at t= 18.9666666667
# recording at t= 19.0
# recording at t= 19.0333333333
# recording at t= 19.0666666667
# recording at t= 19.1
# recording at t= 19.1333333333
# recording at t= 19.1666666667
# recording at t= 19.2
# recording at t= 19.2333333333
# recording at t= 19.2666666667
# recording at t= 19.3
# recording at t= 19.3333333333
# recording at t= 19.3666666667
# recording at t= 19.4
# recording at t= 19.4333333333
# recording at t= 19.4666666667
# recording at t= 19.5
# recording at t= 19.5333333333
# recording at t= 19.5666666667
# recording at t= 19.6
# recording at t= 19.6333333333
# recording at t= 19.6666666667
# recording at t= 19.7
# recording at t= 19.7333333333
# recording at t= 19.7666666667
# recording at t= 19.8
# recording at t= 19.8333333333
# recording at t= 19.8666666667
# recording at t= 19.9
# recording at t= 19.9333333333
# recording at t= 19.9666666667
# recording at t= 20.0
# recording at t= 20.0333333333
# recording at t= 20.0666666667
# recording at t= 20.1
# recording at t= 20.1333333333
# recording at t= 20.1666666667
# recording at t= 20.2
# recording at t= 20.2333333333
# recording at t= 20.2666666667
# recording at t= 20.3
# recording at t= 20.3333333333
# recording at t= 20.3666666667
# recording at t= 20.4
# recording at t= 20.4333333333
# recording at t= 20.4666666667
# recording at t= 20.5
# recording at t= 20.5333333333
# recording at t= 20.5666666667
# recording at t= 20.6
# recording at t= 20.6333333333
# recording at t= 20.6666666667
# recording at t= 20.7
# recording at t= 20.7333333333
# recording at t= 20.7666666667
# recording at t= 20.8
# recording at t= 20.8333333333
# recording at t= 20.8666666667
# recording at t= 20.9
# recording at t= 20.9333333333
# recording at t= 20.9666666667
# recording at t= 21.0
# recording at t= 21.0333333333
# recording at t= 21.0666666667
# recording at t= 21.1
# recording at t= 21.1333333333
# recording at t= 21.1666666667
# recording at t= 21.2
# recording at t= 21.2333333333
# recording at t= 21.2666666667
# recording at t= 21.3
# recording at t= 21.3333333333
# recording at t= 21.3666666667
# recording at t= 21.4
# recording at t= 21.4333333333
# recording at t= 21.4666666667
# recording at t= 21.5
# recording at t= 21.5333333333
# recording at t= 21.5666666667
# recording at t= 21.6
# recording at t= 21.6333333333
# recording at t= 21.6666666667
# recording at t= 21.7
# recording at t= 21.7333333333
# recording at t= 21.7666666667
# recording at t= 21.8
# recording at t= 21.8333333333
# recording at t= 21.8666666667
# recording at t= 21.9
# recording at t= 21.9333333333
# recording at t= 21.9666666667
# recording at t= 22.0
# recording at t= 22.0333333333
# recording at t= 22.0666666667
# recording at t= 22.1
# recording at t= 22.1333333333
# recording at t= 22.1666666667
# recording at t= 22.2
# recording at t= 22.2333333333
# recording at t= 22.2666666667
# recording at t= 22.3
# recording at t= 22.3333333333
# recording at t= 22.3666666667
# recording at t= 22.4
# recording at t= 22.4333333333
# recording at t= 22.4666666667
# recording at t= 22.5
# recording at t= 22.5333333333
# recording at t= 22.5666666667
# recording at t= 22.6
# recording at t= 22.6333333333
# recording at t= 22.6666666667
# recording at t= 22.7
# recording at t= 22.7333333333
# recording at t= 22.7666666667
# recording at t= 22.8
# recording at t= 22.8333333333
# recording at t= 22.8666666667
# recording at t= 22.9
# recording at t= 22.9333333333
# recording at t= 22.9666666667
# recording at t= 23.0
# recording at t= 23.0333333333
# recording at t= 23.0666666667
# recording at t= 23.1
# recording at t= 23.1333333333
# recording at t= 23.1666666667
# recording at t= 23.2
# recording at t= 23.2333333333
# recording at t= 23.2666666667
# recording at t= 23.3
# recording at t= 23.3333333333
# recording at t= 23.3666666667
# recording at t= 23.4
# recording at t= 23.4333333333
# recording at t= 23.4666666667
# recording at t= 23.5
# recording at t= 23.5333333333
# recording at t= 23.5666666667
# recording at t= 23.6
# recording at t= 23.6333333333
# recording at t= 23.6666666667
# recording at t= 23.7
# recording at t= 23.7333333333
# recording at t= 23.7666666667
# recording at t= 23.8
# recording at t= 23.8333333333
# recording at t= 23.8666666667
# recording at t= 23.9
# recording at t= 23.9333333333
# recording at t= 23.9666666667
# recording at t= 24.0
# recording at t= 24.0333333333
# recording at t= 24.0666666667
# recording at t= 24.1
# recording at t= 24.1333333333
# recording at t= 24.1666666667
# recording at t= 24.2
# recording at t= 24.2333333333
# recording at t= 24.2666666667
# recording at t= 24.3
# recording at t= 24.3333333333
# recording at t= 24.3666666667
# recording at t= 24.4
# recording at t= 24.4333333333
# recording at t= 24.4666666667
# recording at t= 24.5
# recording at t= 24.5333333333
# recording at t= 24.5666666667
# recording at t= 24.6
# recording at t= 24.6333333333
# recording at t= 24.6666666667
# recording at t= 24.7
# recording at t= 24.7333333333
# recording at t= 24.7666666667
# recording at t= 24.8
# recording at t= 24.8333333333
# recording at t= 24.8666666667
# recording at t= 24.9
# recording at t= 24.9333333333
# recording at t= 24.9666666667
# recording at t= 25.0
# recording at t= 25.0333333333
# recording at t= 25.0666666667
# recording at t= 25.1
# recording at t= 25.1333333333
# recording at t= 25.1666666667
# recording at t= 25.2
# recording at t= 25.2333333333
# recording at t= 25.2666666667
# recording at t= 25.3
# recording at t= 25.3333333333
# recording at t= 25.3666666667
# recording at t= 25.4
# recording at t= 25.4333333333
# recording at t= 25.4666666667
# recording at t= 25.5
# recording at t= 25.5333333333
# recording at t= 25.5666666667
# recording at t= 25.6
# recording at t= 25.6333333333
# recording at t= 25.6666666667
# recording at t= 25.7
# recording at t= 25.7333333333
# recording at t= 25.7666666667
# recording at t= 25.8
# recording at t= 25.8333333333
# recording at t= 25.8666666667
# recording at t= 25.9
# recording at t= 25.9333333333
# recording at t= 25.9666666667
# recording at t= 26.0
# recording at t= 26.0333333333
# recording at t= 26.0666666667
# recording at t= 26.1
# recording at t= 26.1333333333
# recording at t= 26.1666666667
# recording at t= 26.2
# recording at t= 26.2333333333
# recording at t= 26.2666666667
# recording at t= 26.3
# recording at t= 26.3333333333
# recording at t= 26.3666666667
# recording at t= 26.4
# recording at t= 26.4333333333
# recording at t= 26.4666666667
# recording at t= 26.5
# recording at t= 26.5333333333
# recording at t= 26.5666666667
# recording at t= 26.6
# recording at t= 26.6333333333
# recording at t= 26.6666666667
# recording at t= 26.7
# recording at t= 26.7333333333
# recording at t= 26.7666666667
# recording at t= 26.8
# recording at t= 26.8333333333
# recording at t= 26.8666666667
# recording at t= 26.9
# recording at t= 26.9333333333
# recording at t= 26.9666666667
# recording at t= 27.0
# recording at t= 27.0333333333
# recording at t= 27.0666666667
# recording at t= 27.1
# recording at t= 27.1333333333
# recording at t= 27.1666666667
# recording at t= 27.2
# recording at t= 27.2333333333
# recording at t= 27.2666666667
# recording at t= 27.3
# recording at t= 27.3333333333
# recording at t= 27.3666666667
# recording at t= 27.4
# recording at t= 27.4333333333
# recording at t= 27.4666666667
# recording at t= 27.5
# recording at t= 27.5333333333
# recording at t= 27.5666666667
# recording at t= 27.6
# recording at t= 27.6333333333
# recording at t= 27.6666666667
# recording at t= 27.7
# recording at t= 27.7333333333
# recording at t= 27.7666666667
# recording at t= 27.8
# recording at t= 27.8333333333
# recording at t= 27.8666666667
# recording at t= 27.9
# recording at t= 27.9333333333
# recording at t= 27.9666666667
# recording at t= 28.0
# recording at t= 28.0333333333
# recording at t= 28.0666666667
# recording at t= 28.1
# recording at t= 28.1333333333
# recording at t= 28.1666666667
# recording at t= 28.2
# recording at t= 28.2333333333
# recording at t= 28.2666666667
# recording at t= 28.3
# recording at t= 28.3333333333
# recording at t= 28.3666666667
# recording at t= 28.4
# recording at t= 28.4333333333
# recording at t= 28.4666666667
# recording at t= 28.5
# recording at t= 28.5333333333
# recording at t= 28.5666666667
# recording at t= 28.6
# recording at t= 28.6333333333
# recording at t= 28.6666666667
# recording at t= 28.7
# recording at t= 28.7333333333
# recording at t= 28.7666666667
# recording at t= 28.8
# recording at t= 28.8333333333
# recording at t= 28.8666666667
# recording at t= 28.9
# recording at t= 28.9333333333
# recording at t= 28.9666666667
# recording at t= 29.0
# recording at t= 29.0333333333
# recording at t= 29.0666666667
# recording at t= 29.1
# recording at t= 29.1333333333
# recording at t= 29.1666666667
# recording at t= 29.2
# recording at t= 29.2333333333
# recording at t= 29.2666666667
# recording at t= 29.3
# recording at t= 29.3333333333
# recording at t= 29.3666666667
# recording at t= 29.4
# recording at t= 29.4333333333
# recording at t= 29.4666666667
# recording at t= 29.5
# recording at t= 29.5333333333
# recording at t= 29.5666666667
# recording at t= 29.6
# recording at t= 29.6333333333
# recording at t= 29.6666666667
# recording at t= 29.7
# recording at t= 29.7333333333
# recording at t= 29.7666666667
# recording at t= 29.8
# recording at t= 29.8333333333
# /Users/laurentperrinet/cloud_nas/science/2016-01-13_elasticite_github/posts

# %%
200. * 32. * 60. / 14.
# Out:
# 27428.571428571428

# %%
import matplotlib
matplotlib.use('nbagg')
# %matplotlib inline
import matplotlib.pyplot as plt

z = np.load('../mat/line_contraint.npy')
fig, ax = plt.subplots(figsize=(15, 3))
#_ = ax.plot(z[:, 0])
_ = ax.plot(z[:, 0], z[:, 1:])
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
e = EdgeGrid(N_lame=25, grid_type='line', mode=mode, verb=True, period=30, filename='mat/line_contraint.npy')
e.render(fps=10., duration=30, fname='../files/2015-10-14_elasticite/line_contraint.mp4')
# Out:
# <div align=middle><video loop='1' autoplay='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ## git

# %%
#!git add 2015-10-14\ élasticité,\ control\ scenario.ipynb ../mat/line_contraint.npy
# !git s

# %%
# !git commit -m' scenario line_contraint ' -a

# %%
! git push
